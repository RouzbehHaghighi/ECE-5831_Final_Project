# %% [markdown]
# # Final model

# %%
import pybamm
import os
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd 
from scipy.interpolate import interp1d

parameter_values = pybamm.ParameterValues("Chen2020")

# Set model options for SEI degradation
options = {
    "SEI": "reaction limited", 
    "SEI porosity change": "true",
}

# Update the model with the chosen options
model_with_deg = pybamm.lithium_ion.DFN(options)

max_step_size = 120

solver = pybamm.CasadiSolver(mode="safe", max_step_decrease_count=15,dt_max = max_step_size)

num_cycles =   # Number of cycles

pybamm.set_logging_level("NOTICE")

# Experiment from First Snippet
experiment = pybamm.Experiment(
    [
        "Rest for 10 minutes",
        "Charge at 1 C until 4.2 V",
        "Hold at 4.2 V until 50 mA",
        "Rest for 10 minutes",
        "Discharge at 1 C until 2.5 V",
        "Rest for 10 minutes",
    ] * num_cycles,
    period="1 second"
)

# Run First Simulation
deg_sim = pybamm.Simulation(model_with_deg, parameter_values=parameter_values, experiment=experiment, solver=solver)
deg_solution = deg_sim.solve(initial_soc=0.3)
initial_capacity = deg_solution.summary_variables["Capacity [A.h]"][-1]

# Initialize SOH Storage
initial_soc = 0.3
soh_over_cycles = []
all_cycles_data = []


cyc = []


# Secondary Simulation with Dynamic Experiment Parameters
for cycle_N in range(1, num_cycles + 1):

    # deg_solution = deg_sim.solve()


    # Dynamic Parameters
    lower_SoC = 0.3  # Lower State of Charge
    upper_SoC = 0.7  # Upper State of Charge
    C_rate_charge = 1  # C-rate for charging
    C_rate_discharge = 1  # C-rate for discharging

    charging_current = C_rate_charge * current_capacity  # A
    discharging_current = C_rate_discharge * current_capacity  # A
    initial_lower_Q = lower_SoC * current_capacity  # Ah
    initial_upper_Q = upper_SoC * current_capacity  # Ah
    charge_time = (initial_upper_Q - initial_lower_Q) / charging_current  # h
    discharge_time = (initial_upper_Q - initial_lower_Q) / discharging_current  # h

    # Define the experiment for this cycle
    experiment_N_1 = pybamm.Experiment([
        f"Charge at {charging_current} A until 4.2 V",
        "Hold at 4.2 V for 10 minutes",  # Hold step for safety
        f"Discharge at {discharging_current} A until 2.5 V",
        "Hold at 2.5 V for 10 minutes"  # Hold step for safety
        # Add other steps as necessary
    ])

    # Run the simulation for this cycle
    sim = pybamm.Simulation(model_with_deg, parameter_values=parameter_values, experiment=experiment_N_1, solver=solver)
    # Solve the simulation with initial SoC check
    if lower_SoC >= 0 and lower_SoC <= 1:
        if cycle_N == 1:
            deg_solution = sim.solve(initial_soc=lower_SoC)
        else:
            deg_solution = sim.solve(starting_solution=deg_solution)  # Continue from the previous solution
    else:
        raise ValueError("Initial SoC is out of feasible range (0-1)")
    


    # Update Capacity and SOH for each cycle
    current_capacity = deg_solution.summary_variables["Capacity [A.h]"][-1]
    SOH = current_capacity / initial_capacity * 100
    soh_over_cycles.append(SOH)

    # Extract data for this cycle
    times = deg_solution["Time [s]"].entries
    voltage = deg_solution["Terminal voltage [V]"].entries
    current = deg_solution["Current [A]"].entries

    cycle_numbers = [cycle_N] * len(times)

    soh = [soh_over_cycles[cycle_N-1]] * len(times)  # Repeat SOH for each time point

    dt = np.diff(times, prepend=times[0])  # Time differences for integration
    # Initialize SoC array
    soc = np.zeros_like(times)
    soc[0] = initial_soc
    # Calculate SoC at each time step
    for i in range(1, len(times)):
        charge_added = current[i] * dt[i] / 3600  # Convert to Ah
        soc[i] = soc[i-1] + charge_added / current_capacity
        soc[i] = max(0, min(soc[i], 1))  # Ensure SoC stays within 0 and 1

    # Create a DataFrame for this cycle
    cycle_data = pd.DataFrame({
        "Time [s]": times,
        "Cycle": cycle_numbers,
        "Voltage [V]": voltage,
        "Current [A]": current,
        "State of Charge": soc,
        # "Temperature [K]": temperature,
        "SOH": soh
    })
    all_cycles_data.append(cycle_data)

combined_data = pd.DataFrame(cycle_data)
combined_data.to_excel("battery_data.xlsx", index=False)
# Out:
# 2023-12-11 15:50:06.543 - [NOTICE] callbacks.on_cycle_start(172): Cycle 1/600 (145.305 us elapsed) --------------------
# 2023-12-11 15:50:06.544 - [NOTICE] callbacks.on_step_start(180): Cycle 1/600, step 1/1: Rest for 10 minutes
# 2023-12-11 15:50:07.570 - [NOTICE] callbacks.on_cycle_start(172): Cycle 2/600 (1.027 s elapsed) --------------------
# 2023-12-11 15:50:07.571 - [NOTICE] callbacks.on_step_start(180): Cycle 2/600, step 1/1: Charge at 1 C until 4.2 V
# 2023-12-11 15:50:08.995 - [NOTICE] callbacks.on_cycle_start(172): Cycle 3/600 (2.453 s elapsed) --------------------
# 2023-12-11 15:50:08.997 - [NOTICE] callbacks.on_step_start(180): Cycle 3/600, step 1/1: Hold at 4.2 V until 50 mA
# 2023-12-11 15:50:12.400 - [NOTICE] callbacks.on_cycle_start(172): Cycle 4/600 (5.858 s elapsed) --------------------
# 2023-12-11 15:50:12.402 - [NOTICE] callbacks.on_step_start(180): Cycle 4/600, step 1/1: Rest for 10 minutes
# 2023-12-11 15:50:13.229 - [NOTICE] callbacks.on_cycle_start(172): Cycle 5/600 (6.687 s elapsed) --------------------
# 2023-12-11 15:50:13.230 - [NOTICE] callbacks.on_step_start(180): Cycle 5/600, step 1/1: Discharge at 1 C until 2.5 V
# 2023-12-11 15:50:15.662 - [NOTICE] callbacks.on_cycle_start(172): Cycle 6/600 (9.120 s elapsed) --------------------
# 2023-12-11 15:50:15.664 - [NOTICE] callbacks.on_step_start(180): Cycle 6/600, step 1/1: Rest for 10 minutes
# 2023-12-11 15:50:16.386 - [NOTICE] callbacks.on_cycle_start(172): Cycle 7/600 (9.844 s elapsed) --------------------
# 2023-12-11 15:50:16.387 - [NOTICE] callbacks.on_step_start(180): Cycle 7/600, step 1/1: Rest for 10 minutes
# 2023-12-11 15:50:18.571 - [NOTICE] callbacks.on_cycle_start(172): Cycle 8/600 (12.029 s elapsed) --------------------
# 2023-12-11 15:50:18.572 - [NOTICE] callbacks.on_step_start(180): Cycle 8/600, step 1/1: Charge at 1 C until 4.2 V
# 2023-12-11 15:50:20.231 - [NOTICE] callbacks.on_cycle_start(172): Cycle 9/600 (13.689 s elapsed) --------------------
# 2023-12-11 15:50:20.232 - [NOTICE] callbacks.on_step_start(180): Cycle 9/600, step 1/1: Hold at 4.2 V until 50 mA
# 2023-12-11 15:50:23.147 - [NOTICE] callbacks.on_cycle_start(172): Cycle 10/600 (16.605 s elapsed) --------------------
# 2023-12-11 15:50:23.149 - [NOTICE] callbacks.on_step_start(180): Cycle 10/600, step 1/1: Rest for 10 minutes
# 2023-12-11 15:50:23.908 - [NOTICE] callbacks.on_cycle_start(172): Cycle 11/600 (17.366 s elapsed) --------------------
# 2023-12-11 15:50:23.909 - [NOTICE] callbacks.on_step_start(180): Cycle 11/600, step 1/1: Discharge at 1 C until 2.5 V
# 2023-12-11 15:50:26.190 - [NOTICE] callbacks.on_cycle_start(172): Cycle 12/600 (19.648 s elapsed) --------------------
# 2023-12-11 15:50:26.192 - [NOTICE] callbacks.on_step_start(180): Cycle 12/600, step 1/1: Rest for 10 minutes
# 2023-12-11 15:50:26.961 - [NOTICE] callbacks.on_cycle_start(172): Cycle 13/600 (20.419 s elapsed) --------------------
# 2023-12-11 15:50:26.962 - [NOTICE] callbacks.on_step_start(180): Cycle 13/600, step 1/1: Rest for 10 minutes
# 2023-12-11 15:50:27.658 - [NOTICE] callbacks.on_cycle_start(172): Cycle 14/600 (21.116 s elapsed) --------------------
# 2023-12-11 15:50:27.659 - [NOTICE] callbacks.on_step_start(180): Cycle 14/600, step 1/1: Charge at 1 C until 4.2 V
# 2023-12-11 15:50:29.216 - [NOTICE] callbacks.on_cycle_start(172): Cycle 15/600 (22.674 s elapsed) --------------------
# 2023-12-11 15:50:29.217 - [NOTICE] callbacks.on_step_start(180): Cycle 15/600, step 1/1: Hold at 4.2 V until 50 mA
# 2023-12-11 15:50:32.228 - [NOTICE] callbacks.on_cycle_start(172): Cycle 16/600 (25.687 s elapsed) --------------------
# 2023-12-11 15:50:32.230 - [NOTICE] callbacks.on_step_start(180): Cycle 16/600, step 1/1: Rest for 10 minutes
# 2023-12-11 15:50:32.926 - [NOTICE] callbacks.on_cycle_start(172): Cycle 17/600 (26.384 s elapsed) --------------------
# 2023-12-11 15:50:32.927 - [NOTICE] callbacks.on_step_start(180): Cycle 17/600, step 1/1: Discharge at 1 C until 2.5 V
# 2023-12-11 15:50:35.009 - [NOTICE] callbacks.on_cycle_start(172): Cycle 18/600 (28.468 s elapsed) --------------------
# 2023-12-11 15:50:35.011 - [NOTICE] callbacks.on_step_start(180): Cycle 18/600, step 1/1: Rest for 10 minutes
# 2023-12-11 15:50:35.695 - [NOTICE] callbacks.on_cycle_start(172): Cycle 19/600 (29.154 s elapsed) --------------------
# 2023-12-11 15:50:35.696 - [NOTICE] callbacks.on_step_start(180): Cycle 19/600, step 1/1: Rest for 10 minutes
# 2023-12-11 15:50:36.337 - [NOTICE] callbacks.on_cycle_start(172): Cycle 20/600 (29.796 s elapsed) --------------------
# 2023-12-11 15:50:36.338 - [NOTICE] callbacks.on_step_start(180): Cycle 20/600, step 1/1: Charge at 1 C until 4.2 V
# 2023-12-11 15:50:37.842 - [NOTICE] callbacks.on_cycle_start(172): Cycle 21/600 (31.300 s elapsed) --------------------
# 2023-12-11 15:50:37.843 - [NOTICE] callbacks.on_step_start(180): Cycle 21/600, step 1/1: Hold at 4.2 V until 50 mA
# 2023-12-11 15:50:41.083 - [NOTICE] callbacks.on_cycle_start(172): Cycle 22/600 (34.542 s elapsed) --------------------
# 2023-12-11 15:50:41.085 - [NOTICE] callbacks.on_step_start(180): Cycle 22/600, step 1/1: Rest for 10 minutes
# 2023-12-11 15:50:41.781 - [NOTICE] callbacks.on_cycle_start(172): Cycle 23/600 (35.240 s elapsed) --------------------
# 2023-12-11 15:50:41.782 - [NOTICE] callbacks.on_step_start(180): Cycle 23/600, step 1/1: Discharge at 1 C until 2.5 V
# 2023-12-11 15:50:43.927 - [NOTICE] callbacks.on_cycle_start(172): Cycle 24/600 (37.386 s elapsed) --------------------
# 2023-12-11 15:50:43.929 - [NOTICE] callbacks.on_step_start(180): Cycle 24/600, step 1/1: Rest for 10 minutes
# 2023-12-11 15:50:44.657 - [NOTICE] callbacks.on_cycle_start(172): Cycle 25/600 (38.116 s elapsed) --------------------
# 2023-12-11 15:50:44.658 - [NOTICE] callbacks.on_step_start(180): Cycle 25/600, step 1/1: Rest for 10 minutes
# 2023-12-11 15:50:45.399 - [NOTICE] callbacks.on_cycle_start(172): Cycle 26/600 (38.858 s elapsed) --------------------
# 2023-12-11 15:50:45.400 - [NOTICE] callbacks.on_step_start(180): Cycle 26/600, step 1/1: Charge at 1 C until 4.2 V
# 2023-12-11 15:50:47.041 - [NOTICE] callbacks.on_cycle_start(172): Cycle 27/600 (40.499 s elapsed) --------------------
# 2023-12-11 15:50:47.042 - [NOTICE] callbacks.on_step_start(180): Cycle 27/600, step 1/1: Hold at 4.2 V until 50 mA
# 2023-12-11 15:50:50.127 - [NOTICE] callbacks.on_cycle_start(172): Cycle 28/600 (43.586 s elapsed) --------------------
# 2023-12-11 15:50:50.129 - [NOTICE] callbacks.on_step_start(180): Cycle 28/600, step 1/1: Rest for 10 minutes
# 2023-12-11 15:50:50.871 - [NOTICE] callbacks.on_cycle_start(172): Cycle 29/600 (44.330 s elapsed) --------------------
# 2023-12-11 15:50:50.872 - [NOTICE] callbacks.on_step_start(180): Cycle 29/600, step 1/1: Discharge at 1 C until 2.5 V
# 2023-12-11 15:50:53.044 - [NOTICE] callbacks.on_cycle_start(172): Cycle 30/600 (46.503 s elapsed) --------------------
# 2023-12-11 15:50:53.046 - [NOTICE] callbacks.on_step_start(180): Cycle 30/600, step 1/1: Rest for 10 minutes
# 2023-12-11 15:50:53.759 - [NOTICE] callbacks.on_cycle_start(172): Cycle 31/600 (47.218 s elapsed) --------------------
# 2023-12-11 15:50:53.760 - [NOTICE] callbacks.on_step_start(180): Cycle 31/600, step 1/1: Rest for 10 minutes
# 2023-12-11 15:50:54.426 - [NOTICE] callbacks.on_cycle_start(172): Cycle 32/600 (47.885 s elapsed) --------------------
# 2023-12-11 15:50:54.428 - [NOTICE] callbacks.on_step_start(180): Cycle 32/600, step 1/1: Charge at 1 C until 4.2 V
# 2023-12-11 15:50:56.017 - [NOTICE] callbacks.on_cycle_start(172): Cycle 33/600 (49.476 s elapsed) --------------------
# 2023-12-11 15:50:56.018 - [NOTICE] callbacks.on_step_start(180): Cycle 33/600, step 1/1: Hold at 4.2 V until 50 mA
# 2023-12-11 15:50:58.950 - [NOTICE] callbacks.on_cycle_start(172): Cycle 34/600 (52.409 s elapsed) --------------------
# 2023-12-11 15:50:58.952 - [NOTICE] callbacks.on_step_start(180): Cycle 34/600, step 1/1: Rest for 10 minutes
# 2023-12-11 15:50:59.680 - [NOTICE] callbacks.on_cycle_start(172): Cycle 35/600 (53.139 s elapsed) --------------------
# 2023-12-11 15:50:59.681 - [NOTICE] callbacks.on_step_start(180): Cycle 35/600, step 1/1: Discharge at 1 C until 2.5 V
# 2023-12-11 15:51:02.093 - [NOTICE] callbacks.on_cycle_start(172): Cycle 36/600 (55.552 s elapsed) --------------------
# 2023-12-11 15:51:02.094 - [NOTICE] callbacks.on_step_start(180): Cycle 36/600, step 1/1: Rest for 10 minutes
# 2023-12-11 15:51:02.822 - [NOTICE] callbacks.on_cycle_start(172): Cycle 37/600 (56.282 s elapsed) --------------------
# 2023-12-11 15:51:02.823 - [NOTICE] callbacks.on_step_start(180): Cycle 37/600, step 1/1: Rest for 10 minutes
# 2023-12-11 15:51:03.542 - [NOTICE] callbacks.on_cycle_start(172): Cycle 38/600 (57.002 s elapsed) --------------------
# 2023-12-11 15:51:03.543 - [NOTICE] callbacks.on_step_start(180): Cycle 38/600, step 1/1: Charge at 1 C until 4.2 V
# 2023-12-11 15:51:05.592 - [NOTICE] callbacks.on_cycle_start(172): Cycle 39/600 (59.051 s elapsed) --------------------
# 2023-12-11 15:51:05.593 - [NOTICE] callbacks.on_step_start(180): Cycle 39/600, step 1/1: Hold at 4.2 V until 50 mA
# 2023-12-11 15:51:08.406 - [NOTICE] callbacks.on_cycle_start(172): Cycle 40/600 (1 minute, 2 seconds elapsed) --------------------
# 2023-12-11 15:51:08.407 - [NOTICE] callbacks.on_step_start(180): Cycle 40/600, step 1/1: Rest for 10 minutes
# 2023-12-11 15:51:09.127 - [NOTICE] callbacks.on_cycle_start(172): Cycle 41/600 (1 minute, 3 seconds elapsed) --------------------
# 2023-12-11 15:51:09.128 - [NOTICE] callbacks.on_step_start(180): Cycle 41/600, step 1/1: Discharge at 1 C until 2.5 V
# 2023-12-11 15:51:11.308 - [NOTICE] callbacks.on_cycle_start(172): Cycle 42/600 (1 minute, 5 seconds elapsed) --------------------
# 2023-12-11 15:51:11.309 - [NOTICE] callbacks.on_step_start(180): Cycle 42/600, step 1/1: Rest for 10 minutes
# 2023-12-11 15:51:12.041 - [NOTICE] callbacks.on_cycle_start(172): Cycle 43/600 (1 minute, 6 seconds elapsed) --------------------
# 2023-12-11 15:51:12.042 - [NOTICE] callbacks.on_step_start(180): Cycle 43/600, step 1/1: Rest for 10 minutes
# 2023-12-11 15:51:12.770 - [NOTICE] callbacks.on_cycle_start(172): Cycle 44/600 (1 minute, 6 seconds elapsed) --------------------
# 2023-12-11 15:51:12.771 - [NOTICE] callbacks.on_step_start(180): Cycle 44/600, step 1/1: Charge at 1 C until 4.2 V
# 2023-12-11 15:51:14.391 - [NOTICE] callbacks.on_cycle_start(172): Cycle 45/600 (1 minute, 8 seconds elapsed) --------------------
# 2023-12-11 15:51:14.392 - [NOTICE] callbacks.on_step_start(180): Cycle 45/600, step 1/1: Hold at 4.2 V until 50 mA
# 2023-12-11 15:51:17.480 - [NOTICE] callbacks.on_cycle_start(172): Cycle 46/600 (1 minute, 11 seconds elapsed) --------------------
# 2023-12-11 15:51:17.481 - [NOTICE] callbacks.on_step_start(180): Cycle 46/600, step 1/1: Rest for 10 minutes
# 2023-12-11 15:51:18.230 - [NOTICE] callbacks.on_cycle_start(172): Cycle 47/600 (1 minute, 12 seconds elapsed) --------------------
# 2023-12-11 15:51:18.231 - [NOTICE] callbacks.on_step_start(180): Cycle 47/600, step 1/1: Discharge at 1 C until 2.5 V
# 2023-12-11 15:51:20.438 - [NOTICE] callbacks.on_cycle_start(172): Cycle 48/600 (1 minute, 14 seconds elapsed) --------------------
# 2023-12-11 15:51:20.439 - [NOTICE] callbacks.on_step_start(180): Cycle 48/600, step 1/1: Rest for 10 minutes
# 2023-12-11 15:51:21.173 - [NOTICE] callbacks.on_cycle_start(172): Cycle 49/600 (1 minute, 15 seconds elapsed) --------------------
# 2023-12-11 15:51:21.174 - [NOTICE] callbacks.on_step_start(180): Cycle 49/600, step 1/1: Rest for 10 minutes
# 2023-12-11 15:51:21.881 - [NOTICE] callbacks.on_cycle_start(172): Cycle 50/600 (1 minute, 15 seconds elapsed) --------------------
# 2023-12-11 15:51:21.882 - [NOTICE] callbacks.on_step_start(180): Cycle 50/600, step 1/1: Charge at 1 C until 4.2 V
# 2023-12-11 15:51:23.464 - [NOTICE] callbacks.on_cycle_start(172): Cycle 51/600 (1 minute, 17 seconds elapsed) --------------------
# 2023-12-11 15:51:23.465 - [NOTICE] callbacks.on_step_start(180): Cycle 51/600, step 1/1: Hold at 4.2 V until 50 mA
# 2023-12-11 15:51:26.385 - [NOTICE] callbacks.on_cycle_start(172): Cycle 52/600 (1 minute, 20 seconds elapsed) --------------------
# 2023-12-11 15:51:26.387 - [NOTICE] callbacks.on_step_start(180): Cycle 52/600, step 1/1: Rest for 10 minutes
# 2023-12-11 15:51:27.230 - [NOTICE] callbacks.on_cycle_start(172): Cycle 53/600 (1 minute, 21 seconds elapsed) --------------------
# 2023-12-11 15:51:27.231 - [NOTICE] callbacks.on_step_start(180): Cycle 53/600, step 1/1: Discharge at 1 C until 2.5 V
# 2023-12-11 15:51:29.381 - [NOTICE] callbacks.on_cycle_start(172): Cycle 54/600 (1 minute, 23 seconds elapsed) --------------------
# 2023-12-11 15:51:29.382 - [NOTICE] callbacks.on_step_start(180): Cycle 54/600, step 1/1: Rest for 10 minutes
# 2023-12-11 15:51:30.157 - [NOTICE] callbacks.on_cycle_start(172): Cycle 55/600 (1 minute, 24 seconds elapsed) --------------------
# 2023-12-11 15:51:30.158 - [NOTICE] callbacks.on_step_start(180): Cycle 55/600, step 1/1: Rest for 10 minutes
# 2023-12-11 15:51:30.845 - [NOTICE] callbacks.on_cycle_start(172): Cycle 56/600 (1 minute, 24 seconds elapsed) --------------------
# 2023-12-11 15:51:30.846 - [NOTICE] callbacks.on_step_start(180): Cycle 56/600, step 1/1: Charge at 1 C until 4.2 V
# 2023-12-11 15:51:32.482 - [NOTICE] callbacks.on_cycle_start(172): Cycle 57/600 (1 minute, 26 seconds elapsed) --------------------
# 2023-12-11 15:51:32.483 - [NOTICE] callbacks.on_step_start(180): Cycle 57/600, step 1/1: Hold at 4.2 V until 50 mA
# 2023-12-11 15:51:38.682 - [NOTICE] callbacks.on_cycle_start(172): Cycle 58/600 (1 minute, 32 seconds elapsed) --------------------
# 2023-12-11 15:51:38.685 - [NOTICE] callbacks.on_step_start(180): Cycle 58/600, step 1/1: Rest for 10 minutes
# 2023-12-11 15:51:39.529 - [NOTICE] callbacks.on_cycle_start(172): Cycle 59/600 (1 minute, 33 seconds elapsed) --------------------
# 2023-12-11 15:51:39.530 - [NOTICE] callbacks.on_step_start(180): Cycle 59/600, step 1/1: Discharge at 1 C until 2.5 V
# 2023-12-11 15:51:42.118 - [NOTICE] callbacks.on_cycle_start(172): Cycle 60/600 (1 minute, 36 seconds elapsed) --------------------
# 2023-12-11 15:51:42.120 - [NOTICE] callbacks.on_step_start(180): Cycle 60/600, step 1/1: Rest for 10 minutes
# 2023-12-11 15:51:42.830 - [NOTICE] callbacks.on_cycle_start(172): Cycle 61/600 (1 minute, 36 seconds elapsed) --------------------
# 2023-12-11 15:51:42.831 - [NOTICE] callbacks.on_step_start(180): Cycle 61/600, step 1/1: Rest for 10 minutes
# 2023-12-11 15:51:43.591 - [NOTICE] callbacks.on_cycle_start(172): Cycle 62/600 (1 minute, 37 seconds elapsed) --------------------
# 2023-12-11 15:51:43.592 - [NOTICE] callbacks.on_step_start(180): Cycle 62/600, step 1/1: Charge at 1 C until 4.2 V
# 2023-12-11 15:51:45.594 - [NOTICE] callbacks.on_cycle_start(172): Cycle 63/600 (1 minute, 39 seconds elapsed) --------------------
# 2023-12-11 15:51:45.595 - [NOTICE] callbacks.on_step_start(180): Cycle 63/600, step 1/1: Hold at 4.2 V until 50 mA
# 2023-12-11 15:51:48.881 - [NOTICE] callbacks.on_cycle_start(172): Cycle 64/600 (1 minute, 42 seconds elapsed) --------------------
# 2023-12-11 15:51:48.883 - [NOTICE] callbacks.on_step_start(180): Cycle 64/600, step 1/1: Rest for 10 minutes
# 2023-12-11 15:51:49.659 - [NOTICE] callbacks.on_cycle_start(172): Cycle 65/600 (1 minute, 43 seconds elapsed) --------------------
# 2023-12-11 15:51:49.660 - [NOTICE] callbacks.on_step_start(180): Cycle 65/600, step 1/1: Discharge at 1 C until 2.5 V
# 2023-12-11 15:51:51.717 - [NOTICE] callbacks.on_cycle_start(172): Cycle 66/600 (1 minute, 45 seconds elapsed) --------------------
# 2023-12-11 15:51:51.719 - [NOTICE] callbacks.on_step_start(180): Cycle 66/600, step 1/1: Rest for 10 minutes
# 2023-12-11 15:51:53.652 - [NOTICE] callbacks.on_cycle_start(172): Cycle 67/600 (1 minute, 47 seconds elapsed) --------------------
# 2023-12-11 15:51:53.658 - [NOTICE] callbacks.on_step_start(180): Cycle 67/600, step 1/1: Rest for 10 minutes
# 2023-12-11 15:51:54.583 - [NOTICE] callbacks.on_cycle_start(172): Cycle 68/600 (1 minute, 48 seconds elapsed) --------------------
# 2023-12-11 15:51:54.585 - [NOTICE] callbacks.on_step_start(180): Cycle 68/600, step 1/1: Charge at 1 C until 4.2 V
# 2023-12-11 15:51:58.625 - [NOTICE] callbacks.on_cycle_start(172): Cycle 69/600 (1 minute, 52 seconds elapsed) --------------------
# 2023-12-11 15:51:58.645 - [NOTICE] callbacks.on_step_start(180): Cycle 69/600, step 1/1: Hold at 4.2 V until 50 mA
# 2023-12-11 15:52:03.261 - [NOTICE] callbacks.on_cycle_start(172): Cycle 70/600 (1 minute, 57 seconds elapsed) --------------------
# 2023-12-11 15:52:03.263 - [NOTICE] callbacks.on_step_start(180): Cycle 70/600, step 1/1: Rest for 10 minutes
# 2023-12-11 15:52:03.980 - [NOTICE] callbacks.on_cycle_start(172): Cycle 71/600 (1 minute, 57 seconds elapsed) --------------------
# 2023-12-11 15:52:03.981 - [NOTICE] callbacks.on_step_start(180): Cycle 71/600, step 1/1: Discharge at 1 C until 2.5 V
# 2023-12-11 15:52:06.247 - [NOTICE] callbacks.on_cycle_start(172): Cycle 72/600 (2 minutes, 0 seconds elapsed) --------------------
# 2023-12-11 15:52:06.248 - [NOTICE] callbacks.on_step_start(180): Cycle 72/600, step 1/1: Rest for 10 minutes
# 2023-12-11 15:52:07.025 - [NOTICE] callbacks.on_cycle_start(172): Cycle 73/600 (2 minutes, 0 seconds elapsed) --------------------
# 2023-12-11 15:52:07.026 - [NOTICE] callbacks.on_step_start(180): Cycle 73/600, step 1/1: Rest for 10 minutes
# 2023-12-11 15:52:07.753 - [NOTICE] callbacks.on_cycle_start(172): Cycle 74/600 (2 minutes, 1 second elapsed) --------------------
# 2023-12-11 15:52:07.755 - [NOTICE] callbacks.on_step_start(180): Cycle 74/600, step 1/1: Charge at 1 C until 4.2 V
# 2023-12-11 15:52:09.394 - [NOTICE] callbacks.on_cycle_start(172): Cycle 75/600 (2 minutes, 3 seconds elapsed) --------------------
# 2023-12-11 15:52:09.396 - [NOTICE] callbacks.on_step_start(180): Cycle 75/600, step 1/1: Hold at 4.2 V until 50 mA
# 2023-12-11 15:52:12.483 - [NOTICE] callbacks.on_cycle_start(172): Cycle 76/600 (2 minutes, 6 seconds elapsed) --------------------
# 2023-12-11 15:52:12.485 - [NOTICE] callbacks.on_step_start(180): Cycle 76/600, step 1/1: Rest for 10 minutes
# 2023-12-11 15:52:13.280 - [NOTICE] callbacks.on_cycle_start(172): Cycle 77/600 (2 minutes, 7 seconds elapsed) --------------------
# 2023-12-11 15:52:13.281 - [NOTICE] callbacks.on_step_start(180): Cycle 77/600, step 1/1: Discharge at 1 C until 2.5 V
# 2023-12-11 15:52:15.466 - [NOTICE] callbacks.on_cycle_start(172): Cycle 78/600 (2 minutes, 9 seconds elapsed) --------------------
# 2023-12-11 15:52:15.468 - [NOTICE] callbacks.on_step_start(180): Cycle 78/600, step 1/1: Rest for 10 minutes
# 2023-12-11 15:52:16.180 - [NOTICE] callbacks.on_cycle_start(172): Cycle 79/600 (2 minutes, 10 seconds elapsed) --------------------
# 2023-12-11 15:52:16.182 - [NOTICE] callbacks.on_step_start(180): Cycle 79/600, step 1/1: Rest for 10 minutes
# 2023-12-11 15:52:18.108 - [NOTICE] callbacks.on_cycle_start(172): Cycle 80/600 (2 minutes, 12 seconds elapsed) --------------------
# 2023-12-11 15:52:18.109 - [NOTICE] callbacks.on_step_start(180): Cycle 80/600, step 1/1: Charge at 1 C until 4.2 V
# 2023-12-11 15:52:19.633 - [NOTICE] callbacks.on_cycle_start(172): Cycle 81/600 (2 minutes, 13 seconds elapsed) --------------------
# 2023-12-11 15:52:19.636 - [NOTICE] callbacks.on_step_start(180): Cycle 81/600, step 1/1: Hold at 4.2 V until 50 mA
# 2023-12-11 15:52:22.494 - [NOTICE] callbacks.on_cycle_start(172): Cycle 82/600 (2 minutes, 16 seconds elapsed) --------------------
# 2023-12-11 15:52:22.496 - [NOTICE] callbacks.on_step_start(180): Cycle 82/600, step 1/1: Rest for 10 minutes
# 2023-12-11 15:52:23.186 - [NOTICE] callbacks.on_cycle_start(172): Cycle 83/600 (2 minutes, 17 seconds elapsed) --------------------
# 2023-12-11 15:52:23.187 - [NOTICE] callbacks.on_step_start(180): Cycle 83/600, step 1/1: Discharge at 1 C until 2.5 V
# 2023-12-11 15:52:25.194 - [NOTICE] callbacks.on_cycle_start(172): Cycle 84/600 (2 minutes, 19 seconds elapsed) --------------------
# 2023-12-11 15:52:25.195 - [NOTICE] callbacks.on_step_start(180): Cycle 84/600, step 1/1: Rest for 10 minutes
# 2023-12-11 15:52:25.888 - [NOTICE] callbacks.on_cycle_start(172): Cycle 85/600 (2 minutes, 19 seconds elapsed) --------------------
# 2023-12-11 15:52:25.889 - [NOTICE] callbacks.on_step_start(180): Cycle 85/600, step 1/1: Rest for 10 minutes
# 2023-12-11 15:52:26.543 - [NOTICE] callbacks.on_cycle_start(172): Cycle 86/600 (2 minutes, 20 seconds elapsed) --------------------
# 2023-12-11 15:52:26.544 - [NOTICE] callbacks.on_step_start(180): Cycle 86/600, step 1/1: Charge at 1 C until 4.2 V
# 2023-12-11 15:52:28.041 - [NOTICE] callbacks.on_cycle_start(172): Cycle 87/600 (2 minutes, 22 seconds elapsed) --------------------
# 2023-12-11 15:52:28.042 - [NOTICE] callbacks.on_step_start(180): Cycle 87/600, step 1/1: Hold at 4.2 V until 50 mA
# 2023-12-11 15:52:30.756 - [NOTICE] callbacks.on_cycle_start(172): Cycle 88/600 (2 minutes, 24 seconds elapsed) --------------------
# 2023-12-11 15:52:30.757 - [NOTICE] callbacks.on_step_start(180): Cycle 88/600, step 1/1: Rest for 10 minutes
# 2023-12-11 15:52:31.445 - [NOTICE] callbacks.on_cycle_start(172): Cycle 89/600 (2 minutes, 25 seconds elapsed) --------------------
# 2023-12-11 15:52:31.446 - [NOTICE] callbacks.on_step_start(180): Cycle 89/600, step 1/1: Discharge at 1 C until 2.5 V
# 2023-12-11 15:52:33.451 - [NOTICE] callbacks.on_cycle_start(172): Cycle 90/600 (2 minutes, 27 seconds elapsed) --------------------
# 2023-12-11 15:52:33.452 - [NOTICE] callbacks.on_step_start(180): Cycle 90/600, step 1/1: Rest for 10 minutes
# 2023-12-11 15:52:34.144 - [NOTICE] callbacks.on_cycle_start(172): Cycle 91/600 (2 minutes, 28 seconds elapsed) --------------------
# 2023-12-11 15:52:34.145 - [NOTICE] callbacks.on_step_start(180): Cycle 91/600, step 1/1: Rest for 10 minutes
# 2023-12-11 15:52:34.813 - [NOTICE] callbacks.on_cycle_start(172): Cycle 92/600 (2 minutes, 28 seconds elapsed) --------------------
# 2023-12-11 15:52:34.814 - [NOTICE] callbacks.on_step_start(180): Cycle 92/600, step 1/1: Charge at 1 C until 4.2 V
# 2023-12-11 15:52:36.285 - [NOTICE] callbacks.on_cycle_start(172): Cycle 93/600 (2 minutes, 30 seconds elapsed) --------------------
# 2023-12-11 15:52:36.287 - [NOTICE] callbacks.on_step_start(180): Cycle 93/600, step 1/1: Hold at 4.2 V until 50 mA
# 2023-12-11 15:52:39.036 - [NOTICE] callbacks.on_cycle_start(172): Cycle 94/600 (2 minutes, 32 seconds elapsed) --------------------
# 2023-12-11 15:52:39.038 - [NOTICE] callbacks.on_step_start(180): Cycle 94/600, step 1/1: Rest for 10 minutes
# 2023-12-11 15:52:39.714 - [NOTICE] callbacks.on_cycle_start(172): Cycle 95/600 (2 minutes, 33 seconds elapsed) --------------------
# 2023-12-11 15:52:39.715 - [NOTICE] callbacks.on_step_start(180): Cycle 95/600, step 1/1: Discharge at 1 C until 2.5 V
# 2023-12-11 15:52:42.038 - [NOTICE] callbacks.on_cycle_start(172): Cycle 96/600 (2 minutes, 36 seconds elapsed) --------------------
# 2023-12-11 15:52:42.039 - [NOTICE] callbacks.on_step_start(180): Cycle 96/600, step 1/1: Rest for 10 minutes
# 2023-12-11 15:52:43.871 - [NOTICE] callbacks.on_cycle_start(172): Cycle 97/600 (2 minutes, 37 seconds elapsed) --------------------
# 2023-12-11 15:52:43.872 - [NOTICE] callbacks.on_step_start(180): Cycle 97/600, step 1/1: Rest for 10 minutes
# 2023-12-11 15:52:46.157 - [NOTICE] callbacks.on_cycle_start(172): Cycle 98/600 (2 minutes, 40 seconds elapsed) --------------------
# 2023-12-11 15:52:46.160 - [NOTICE] callbacks.on_step_start(180): Cycle 98/600, step 1/1: Charge at 1 C until 4.2 V
# 2023-12-11 15:52:48.920 - [NOTICE] callbacks.on_cycle_start(172): Cycle 99/600 (2 minutes, 42 seconds elapsed) --------------------
# 2023-12-11 15:52:48.921 - [NOTICE] callbacks.on_step_start(180): Cycle 99/600, step 1/1: Hold at 4.2 V until 50 mA
# 2023-12-11 15:52:52.119 - [NOTICE] callbacks.on_cycle_start(172): Cycle 100/600 (2 minutes, 46 seconds elapsed) --------------------
# 2023-12-11 15:52:52.121 - [NOTICE] callbacks.on_step_start(180): Cycle 100/600, step 1/1: Rest for 10 minutes
# 2023-12-11 15:52:52.828 - [NOTICE] callbacks.on_cycle_start(172): Cycle 101/600 (2 minutes, 46 seconds elapsed) --------------------
# 2023-12-11 15:52:52.829 - [NOTICE] callbacks.on_step_start(180): Cycle 101/600, step 1/1: Discharge at 1 C until 2.5 V
# 2023-12-11 15:52:54.928 - [NOTICE] callbacks.on_cycle_start(172): Cycle 102/600 (2 minutes, 48 seconds elapsed) --------------------
# 2023-12-11 15:52:54.929 - [NOTICE] callbacks.on_step_start(180): Cycle 102/600, step 1/1: Rest for 10 minutes
# 2023-12-11 15:52:55.654 - [NOTICE] callbacks.on_cycle_start(172): Cycle 103/600 (2 minutes, 49 seconds elapsed) --------------------
# 2023-12-11 15:52:55.655 - [NOTICE] callbacks.on_step_start(180): Cycle 103/600, step 1/1: Rest for 10 minutes
# 2023-12-11 15:52:56.327 - [NOTICE] callbacks.on_cycle_start(172): Cycle 104/600 (2 minutes, 50 seconds elapsed) --------------------
# 2023-12-11 15:52:56.328 - [NOTICE] callbacks.on_step_start(180): Cycle 104/600, step 1/1: Charge at 1 C until 4.2 V
# 2023-12-11 15:52:57.829 - [NOTICE] callbacks.on_cycle_start(172): Cycle 105/600 (2 minutes, 51 seconds elapsed) --------------------
# 2023-12-11 15:52:57.830 - [NOTICE] callbacks.on_step_start(180): Cycle 105/600, step 1/1: Hold at 4.2 V until 50 mA
# 2023-12-11 15:53:03.715 - [NOTICE] callbacks.on_cycle_start(172): Cycle 106/600 (2 minutes, 57 seconds elapsed) --------------------
# 2023-12-11 15:53:03.717 - [NOTICE] callbacks.on_step_start(180): Cycle 106/600, step 1/1: Rest for 10 minutes
# 2023-12-11 15:53:04.562 - [NOTICE] callbacks.on_cycle_start(172): Cycle 107/600 (2 minutes, 58 seconds elapsed) --------------------
# 2023-12-11 15:53:04.563 - [NOTICE] callbacks.on_step_start(180): Cycle 107/600, step 1/1: Discharge at 1 C until 2.5 V
# 2023-12-11 15:53:06.720 - [NOTICE] callbacks.on_cycle_start(172): Cycle 108/600 (3 minutes, 0 seconds elapsed) --------------------
# 2023-12-11 15:53:06.721 - [NOTICE] callbacks.on_step_start(180): Cycle 108/600, step 1/1: Rest for 10 minutes
# 2023-12-11 15:53:07.444 - [NOTICE] callbacks.on_cycle_start(172): Cycle 109/600 (3 minutes, 1 second elapsed) --------------------
# 2023-12-11 15:53:07.445 - [NOTICE] callbacks.on_step_start(180): Cycle 109/600, step 1/1: Rest for 10 minutes
# 2023-12-11 15:53:08.117 - [NOTICE] callbacks.on_cycle_start(172): Cycle 110/600 (3 minutes, 2 seconds elapsed) --------------------
# 2023-12-11 15:53:08.118 - [NOTICE] callbacks.on_step_start(180): Cycle 110/600, step 1/1: Charge at 1 C until 4.2 V
# 2023-12-11 15:53:09.675 - [NOTICE] callbacks.on_cycle_start(172): Cycle 111/600 (3 minutes, 3 seconds elapsed) --------------------
# 2023-12-11 15:53:09.676 - [NOTICE] callbacks.on_step_start(180): Cycle 111/600, step 1/1: Hold at 4.2 V until 50 mA
# 2023-12-11 15:53:12.535 - [NOTICE] callbacks.on_cycle_start(172): Cycle 112/600 (3 minutes, 6 seconds elapsed) --------------------
# 2023-12-11 15:53:12.537 - [NOTICE] callbacks.on_step_start(180): Cycle 112/600, step 1/1: Rest for 10 minutes
# 2023-12-11 15:53:13.273 - [NOTICE] callbacks.on_cycle_start(172): Cycle 113/600 (3 minutes, 7 seconds elapsed) --------------------
# 2023-12-11 15:53:13.274 - [NOTICE] callbacks.on_step_start(180): Cycle 113/600, step 1/1: Discharge at 1 C until 2.5 V
# 2023-12-11 15:53:15.315 - [NOTICE] callbacks.on_cycle_start(172): Cycle 114/600 (3 minutes, 9 seconds elapsed) --------------------
# 2023-12-11 15:53:15.316 - [NOTICE] callbacks.on_step_start(180): Cycle 114/600, step 1/1: Rest for 10 minutes
# 2023-12-11 15:53:16.029 - [NOTICE] callbacks.on_cycle_start(172): Cycle 115/600 (3 minutes, 9 seconds elapsed) --------------------
# 2023-12-11 15:53:16.030 - [NOTICE] callbacks.on_step_start(180): Cycle 115/600, step 1/1: Rest for 10 minutes
# 2023-12-11 15:53:16.696 - [NOTICE] callbacks.on_cycle_start(172): Cycle 116/600 (3 minutes, 10 seconds elapsed) --------------------
# 2023-12-11 15:53:16.697 - [NOTICE] callbacks.on_step_start(180): Cycle 116/600, step 1/1: Charge at 1 C until 4.2 V
# 2023-12-11 15:53:18.241 - [NOTICE] callbacks.on_cycle_start(172): Cycle 117/600 (3 minutes, 12 seconds elapsed) --------------------
# 2023-12-11 15:53:18.242 - [NOTICE] callbacks.on_step_start(180): Cycle 117/600, step 1/1: Hold at 4.2 V until 50 mA
# 2023-12-11 15:53:21.050 - [NOTICE] callbacks.on_cycle_start(172): Cycle 118/600 (3 minutes, 15 seconds elapsed) --------------------
# 2023-12-11 15:53:21.051 - [NOTICE] callbacks.on_step_start(180): Cycle 118/600, step 1/1: Rest for 10 minutes
# 2023-12-11 15:53:21.744 - [NOTICE] callbacks.on_cycle_start(172): Cycle 119/600 (3 minutes, 15 seconds elapsed) --------------------
# 2023-12-11 15:53:21.745 - [NOTICE] callbacks.on_step_start(180): Cycle 119/600, step 1/1: Discharge at 1 C until 2.5 V
# 2023-12-11 15:53:23.745 - [NOTICE] callbacks.on_cycle_start(172): Cycle 120/600 (3 minutes, 17 seconds elapsed) --------------------
# 2023-12-11 15:53:23.746 - [NOTICE] callbacks.on_step_start(180): Cycle 120/600, step 1/1: Rest for 10 minutes
# 2023-12-11 15:53:24.449 - [NOTICE] callbacks.on_cycle_start(172): Cycle 121/600 (3 minutes, 18 seconds elapsed) --------------------
# 2023-12-11 15:53:24.450 - [NOTICE] callbacks.on_step_start(180): Cycle 121/600, step 1/1: Rest for 10 minutes
# 2023-12-11 15:53:25.106 - [NOTICE] callbacks.on_cycle_start(172): Cycle 122/600 (3 minutes, 19 seconds elapsed) --------------------
# 2023-12-11 15:53:25.107 - [NOTICE] callbacks.on_step_start(180): Cycle 122/600, step 1/1: Charge at 1 C until 4.2 V
# 2023-12-11 15:53:26.625 - [NOTICE] callbacks.on_cycle_start(172): Cycle 123/600 (3 minutes, 20 seconds elapsed) --------------------
# 2023-12-11 15:53:26.626 - [NOTICE] callbacks.on_step_start(180): Cycle 123/600, step 1/1: Hold at 4.2 V until 50 mA
# 2023-12-11 15:53:29.445 - [NOTICE] callbacks.on_cycle_start(172): Cycle 124/600 (3 minutes, 23 seconds elapsed) --------------------
# 2023-12-11 15:53:29.446 - [NOTICE] callbacks.on_step_start(180): Cycle 124/600, step 1/1: Rest for 10 minutes
# 2023-12-11 15:53:30.120 - [NOTICE] callbacks.on_cycle_start(172): Cycle 125/600 (3 minutes, 24 seconds elapsed) --------------------
# 2023-12-11 15:53:30.121 - [NOTICE] callbacks.on_step_start(180): Cycle 125/600, step 1/1: Discharge at 1 C until 2.5 V
# 2023-12-11 15:53:32.126 - [NOTICE] callbacks.on_cycle_start(172): Cycle 126/600 (3 minutes, 26 seconds elapsed) --------------------
# 2023-12-11 15:53:32.127 - [NOTICE] callbacks.on_step_start(180): Cycle 126/600, step 1/1: Rest for 10 minutes
# 2023-12-11 15:53:32.827 - [NOTICE] callbacks.on_cycle_start(172): Cycle 127/600 (3 minutes, 26 seconds elapsed) --------------------
# 2023-12-11 15:53:32.828 - [NOTICE] callbacks.on_step_start(180): Cycle 127/600, step 1/1: Rest for 10 minutes
# 2023-12-11 15:53:33.487 - [NOTICE] callbacks.on_cycle_start(172): Cycle 128/600 (3 minutes, 27 seconds elapsed) --------------------
# 2023-12-11 15:53:33.488 - [NOTICE] callbacks.on_step_start(180): Cycle 128/600, step 1/1: Charge at 1 C until 4.2 V
# 2023-12-11 15:53:34.984 - [NOTICE] callbacks.on_cycle_start(172): Cycle 129/600 (3 minutes, 28 seconds elapsed) --------------------
# 2023-12-11 15:53:34.986 - [NOTICE] callbacks.on_step_start(180): Cycle 129/600, step 1/1: Hold at 4.2 V until 50 mA
# 2023-12-11 15:53:37.741 - [NOTICE] callbacks.on_cycle_start(172): Cycle 130/600 (3 minutes, 31 seconds elapsed) --------------------
# 2023-12-11 15:53:37.744 - [NOTICE] callbacks.on_step_start(180): Cycle 130/600, step 1/1: Rest for 10 minutes
# 2023-12-11 15:53:38.422 - [NOTICE] callbacks.on_cycle_start(172): Cycle 131/600 (3 minutes, 32 seconds elapsed) --------------------
# 2023-12-11 15:53:38.422 - [NOTICE] callbacks.on_step_start(180): Cycle 131/600, step 1/1: Discharge at 1 C until 2.5 V
# 2023-12-11 15:53:40.408 - [NOTICE] callbacks.on_cycle_start(172): Cycle 132/600 (3 minutes, 34 seconds elapsed) --------------------
# 2023-12-11 15:53:40.410 - [NOTICE] callbacks.on_step_start(180): Cycle 132/600, step 1/1: Rest for 10 minutes
# 2023-12-11 15:53:41.123 - [NOTICE] callbacks.on_cycle_start(172): Cycle 133/600 (3 minutes, 35 seconds elapsed) --------------------
# 2023-12-11 15:53:41.124 - [NOTICE] callbacks.on_step_start(180): Cycle 133/600, step 1/1: Rest for 10 minutes
# 2023-12-11 15:53:41.788 - [NOTICE] callbacks.on_cycle_start(172): Cycle 134/600 (3 minutes, 35 seconds elapsed) --------------------
# 2023-12-11 15:53:41.789 - [NOTICE] callbacks.on_step_start(180): Cycle 134/600, step 1/1: Charge at 1 C until 4.2 V
# 2023-12-11 15:53:44.082 - [NOTICE] callbacks.on_cycle_start(172): Cycle 135/600 (3 minutes, 38 seconds elapsed) --------------------
# 2023-12-11 15:53:44.083 - [NOTICE] callbacks.on_step_start(180): Cycle 135/600, step 1/1: Hold at 4.2 V until 50 mA
# 2023-12-11 15:53:46.872 - [NOTICE] callbacks.on_cycle_start(172): Cycle 136/600 (3 minutes, 40 seconds elapsed) --------------------
# 2023-12-11 15:53:46.874 - [NOTICE] callbacks.on_step_start(180): Cycle 136/600, step 1/1: Rest for 10 minutes
# 2023-12-11 15:53:47.553 - [NOTICE] callbacks.on_cycle_start(172): Cycle 137/600 (3 minutes, 41 seconds elapsed) --------------------
# 2023-12-11 15:53:47.554 - [NOTICE] callbacks.on_step_start(180): Cycle 137/600, step 1/1: Discharge at 1 C until 2.5 V
# 2023-12-11 15:53:49.582 - [NOTICE] callbacks.on_cycle_start(172): Cycle 138/600 (3 minutes, 43 seconds elapsed) --------------------
# 2023-12-11 15:53:49.585 - [NOTICE] callbacks.on_step_start(180): Cycle 138/600, step 1/1: Rest for 10 minutes
# 2023-12-11 15:53:50.290 - [NOTICE] callbacks.on_cycle_start(172): Cycle 139/600 (3 minutes, 44 seconds elapsed) --------------------
# 2023-12-11 15:53:50.291 - [NOTICE] callbacks.on_step_start(180): Cycle 139/600, step 1/1: Rest for 10 minutes
# 2023-12-11 15:53:50.951 - [NOTICE] callbacks.on_cycle_start(172): Cycle 140/600 (3 minutes, 44 seconds elapsed) --------------------
# 2023-12-11 15:53:50.952 - [NOTICE] callbacks.on_step_start(180): Cycle 140/600, step 1/1: Charge at 1 C until 4.2 V
# 2023-12-11 15:53:52.520 - [NOTICE] callbacks.on_cycle_start(172): Cycle 141/600 (3 minutes, 46 seconds elapsed) --------------------
# 2023-12-11 15:53:52.521 - [NOTICE] callbacks.on_step_start(180): Cycle 141/600, step 1/1: Hold at 4.2 V until 50 mA
# 2023-12-11 15:53:55.541 - [NOTICE] callbacks.on_cycle_start(172): Cycle 142/600 (3 minutes, 49 seconds elapsed) --------------------
# 2023-12-11 15:53:55.543 - [NOTICE] callbacks.on_step_start(180): Cycle 142/600, step 1/1: Rest for 10 minutes
# 2023-12-11 15:53:56.256 - [NOTICE] callbacks.on_cycle_start(172): Cycle 143/600 (3 minutes, 50 seconds elapsed) --------------------
# 2023-12-11 15:53:56.257 - [NOTICE] callbacks.on_step_start(180): Cycle 143/600, step 1/1: Discharge at 1 C until 2.5 V
# 2023-12-11 15:53:58.406 - [NOTICE] callbacks.on_cycle_start(172): Cycle 144/600 (3 minutes, 52 seconds elapsed) --------------------
# 2023-12-11 15:53:58.407 - [NOTICE] callbacks.on_step_start(180): Cycle 144/600, step 1/1: Rest for 10 minutes
# 2023-12-11 15:53:59.162 - [NOTICE] callbacks.on_cycle_start(172): Cycle 145/600 (3 minutes, 53 seconds elapsed) --------------------
# 2023-12-11 15:53:59.163 - [NOTICE] callbacks.on_step_start(180): Cycle 145/600, step 1/1: Rest for 10 minutes
# 2023-12-11 15:53:59.836 - [NOTICE] callbacks.on_cycle_start(172): Cycle 146/600 (3 minutes, 53 seconds elapsed) --------------------
# 2023-12-11 15:53:59.837 - [NOTICE] callbacks.on_step_start(180): Cycle 146/600, step 1/1: Charge at 1 C until 4.2 V
# 2023-12-11 15:54:01.386 - [NOTICE] callbacks.on_cycle_start(172): Cycle 147/600 (3 minutes, 55 seconds elapsed) --------------------
# 2023-12-11 15:54:01.387 - [NOTICE] callbacks.on_step_start(180): Cycle 147/600, step 1/1: Hold at 4.2 V until 50 mA
# 2023-12-11 15:54:04.319 - [NOTICE] callbacks.on_cycle_start(172): Cycle 148/600 (3 minutes, 58 seconds elapsed) --------------------
# 2023-12-11 15:54:04.321 - [NOTICE] callbacks.on_step_start(180): Cycle 148/600, step 1/1: Rest for 10 minutes
# 2023-12-11 15:54:05.086 - [NOTICE] callbacks.on_cycle_start(172): Cycle 149/600 (3 minutes, 59 seconds elapsed) --------------------
# 2023-12-11 15:54:05.087 - [NOTICE] callbacks.on_step_start(180): Cycle 149/600, step 1/1: Discharge at 1 C until 2.5 V
# 2023-12-11 15:54:07.245 - [NOTICE] callbacks.on_cycle_start(172): Cycle 150/600 (4 minutes, 1 second elapsed) --------------------
# 2023-12-11 15:54:07.247 - [NOTICE] callbacks.on_step_start(180): Cycle 150/600, step 1/1: Rest for 10 minutes
# 2023-12-11 15:54:08.011 - [NOTICE] callbacks.on_cycle_start(172): Cycle 151/600 (4 minutes, 1 second elapsed) --------------------
# 2023-12-11 15:54:08.012 - [NOTICE] callbacks.on_step_start(180): Cycle 151/600, step 1/1: Rest for 10 minutes
# 2023-12-11 15:54:08.769 - [NOTICE] callbacks.on_cycle_start(172): Cycle 152/600 (4 minutes, 2 seconds elapsed) --------------------
# 2023-12-11 15:54:08.770 - [NOTICE] callbacks.on_step_start(180): Cycle 152/600, step 1/1: Charge at 1 C until 4.2 V
# 2023-12-11 15:54:10.427 - [NOTICE] callbacks.on_cycle_start(172): Cycle 153/600 (4 minutes, 4 seconds elapsed) --------------------
# 2023-12-11 15:54:10.428 - [NOTICE] callbacks.on_step_start(180): Cycle 153/600, step 1/1: Hold at 4.2 V until 50 mA
# 2023-12-11 15:54:13.283 - [NOTICE] callbacks.on_cycle_start(172): Cycle 154/600 (4 minutes, 7 seconds elapsed) --------------------
# 2023-12-11 15:54:13.285 - [NOTICE] callbacks.on_step_start(180): Cycle 154/600, step 1/1: Rest for 10 minutes
# 2023-12-11 15:54:14.033 - [NOTICE] callbacks.on_cycle_start(172): Cycle 155/600 (4 minutes, 7 seconds elapsed) --------------------
# 2023-12-11 15:54:14.034 - [NOTICE] callbacks.on_step_start(180): Cycle 155/600, step 1/1: Discharge at 1 C until 2.5 V
# 2023-12-11 15:54:16.089 - [NOTICE] callbacks.on_cycle_start(172): Cycle 156/600 (4 minutes, 10 seconds elapsed) --------------------
# 2023-12-11 15:54:16.093 - [NOTICE] callbacks.on_step_start(180): Cycle 156/600, step 1/1: Rest for 10 minutes
# 2023-12-11 15:54:16.837 - [NOTICE] callbacks.on_cycle_start(172): Cycle 157/600 (4 minutes, 10 seconds elapsed) --------------------
# 2023-12-11 15:54:16.838 - [NOTICE] callbacks.on_step_start(180): Cycle 157/600, step 1/1: Rest for 10 minutes
# 2023-12-11 15:54:17.522 - [NOTICE] callbacks.on_cycle_start(172): Cycle 158/600 (4 minutes, 11 seconds elapsed) --------------------
# 2023-12-11 15:54:17.522 - [NOTICE] callbacks.on_step_start(180): Cycle 158/600, step 1/1: Charge at 1 C until 4.2 V
# 2023-12-11 15:54:19.158 - [NOTICE] callbacks.on_cycle_start(172): Cycle 159/600 (4 minutes, 13 seconds elapsed) --------------------
# 2023-12-11 15:54:19.159 - [NOTICE] callbacks.on_step_start(180): Cycle 159/600, step 1/1: Hold at 4.2 V until 50 mA
# 2023-12-11 15:54:22.568 - [NOTICE] callbacks.on_cycle_start(172): Cycle 160/600 (4 minutes, 16 seconds elapsed) --------------------
# 2023-12-11 15:54:22.570 - [NOTICE] callbacks.on_step_start(180): Cycle 160/600, step 1/1: Rest for 10 minutes
# 2023-12-11 15:54:23.818 - [NOTICE] callbacks.on_cycle_start(172): Cycle 161/600 (4 minutes, 17 seconds elapsed) --------------------
# 2023-12-11 15:54:23.820 - [NOTICE] callbacks.on_step_start(180): Cycle 161/600, step 1/1: Discharge at 1 C until 2.5 V
# 2023-12-11 15:54:26.366 - [NOTICE] callbacks.on_cycle_start(172): Cycle 162/600 (4 minutes, 20 seconds elapsed) --------------------
# 2023-12-11 15:54:26.368 - [NOTICE] callbacks.on_step_start(180): Cycle 162/600, step 1/1: Rest for 10 minutes
# 2023-12-11 15:54:27.205 - [NOTICE] callbacks.on_cycle_start(172): Cycle 163/600 (4 minutes, 21 seconds elapsed) --------------------
# 2023-12-11 15:54:27.207 - [NOTICE] callbacks.on_step_start(180): Cycle 163/600, step 1/1: Rest for 10 minutes
# 2023-12-11 15:54:28.001 - [NOTICE] callbacks.on_cycle_start(172): Cycle 164/600 (4 minutes, 21 seconds elapsed) --------------------
# 2023-12-11 15:54:28.002 - [NOTICE] callbacks.on_step_start(180): Cycle 164/600, step 1/1: Charge at 1 C until 4.2 V
# 2023-12-11 15:54:29.570 - [NOTICE] callbacks.on_cycle_start(172): Cycle 165/600 (4 minutes, 23 seconds elapsed) --------------------
# 2023-12-11 15:54:29.571 - [NOTICE] callbacks.on_step_start(180): Cycle 165/600, step 1/1: Hold at 4.2 V until 50 mA
# 2023-12-11 15:54:33.019 - [NOTICE] callbacks.on_cycle_start(172): Cycle 166/600 (4 minutes, 26 seconds elapsed) --------------------
# 2023-12-11 15:54:33.021 - [NOTICE] callbacks.on_step_start(180): Cycle 166/600, step 1/1: Rest for 10 minutes
# 2023-12-11 15:54:33.699 - [NOTICE] callbacks.on_cycle_start(172): Cycle 167/600 (4 minutes, 27 seconds elapsed) --------------------
# 2023-12-11 15:54:33.701 - [NOTICE] callbacks.on_step_start(180): Cycle 167/600, step 1/1: Discharge at 1 C until 2.5 V
# 2023-12-11 15:54:37.873 - [NOTICE] callbacks.on_cycle_start(172): Cycle 168/600 (4 minutes, 31 seconds elapsed) --------------------
# 2023-12-11 15:54:37.875 - [NOTICE] callbacks.on_step_start(180): Cycle 168/600, step 1/1: Rest for 10 minutes
# 2023-12-11 15:54:38.598 - [NOTICE] callbacks.on_cycle_start(172): Cycle 169/600 (4 minutes, 32 seconds elapsed) --------------------
# 2023-12-11 15:54:38.599 - [NOTICE] callbacks.on_step_start(180): Cycle 169/600, step 1/1: Rest for 10 minutes
# 2023-12-11 15:54:39.286 - [NOTICE] callbacks.on_cycle_start(172): Cycle 170/600 (4 minutes, 33 seconds elapsed) --------------------
# 2023-12-11 15:54:39.289 - [NOTICE] callbacks.on_step_start(180): Cycle 170/600, step 1/1: Charge at 1 C until 4.2 V
# 2023-12-11 15:54:40.832 - [NOTICE] callbacks.on_cycle_start(172): Cycle 171/600 (4 minutes, 34 seconds elapsed) --------------------
# 2023-12-11 15:54:40.834 - [NOTICE] callbacks.on_step_start(180): Cycle 171/600, step 1/1: Hold at 4.2 V until 50 mA
# 2023-12-11 15:54:43.777 - [NOTICE] callbacks.on_cycle_start(172): Cycle 172/600 (4 minutes, 37 seconds elapsed) --------------------
# 2023-12-11 15:54:43.779 - [NOTICE] callbacks.on_step_start(180): Cycle 172/600, step 1/1: Rest for 10 minutes
# 2023-12-11 15:54:44.486 - [NOTICE] callbacks.on_cycle_start(172): Cycle 173/600 (4 minutes, 38 seconds elapsed) --------------------
# 2023-12-11 15:54:44.487 - [NOTICE] callbacks.on_step_start(180): Cycle 173/600, step 1/1: Discharge at 1 C until 2.5 V
# 2023-12-11 15:54:46.591 - [NOTICE] callbacks.on_cycle_start(172): Cycle 174/600 (4 minutes, 40 seconds elapsed) --------------------
# 2023-12-11 15:54:46.593 - [NOTICE] callbacks.on_step_start(180): Cycle 174/600, step 1/1: Rest for 10 minutes
# 2023-12-11 15:54:47.336 - [NOTICE] callbacks.on_cycle_start(172): Cycle 175/600 (4 minutes, 41 seconds elapsed) --------------------
# 2023-12-11 15:54:47.337 - [NOTICE] callbacks.on_step_start(180): Cycle 175/600, step 1/1: Rest for 10 minutes
# 2023-12-11 15:54:48.049 - [NOTICE] callbacks.on_cycle_start(172): Cycle 176/600 (4 minutes, 42 seconds elapsed) --------------------
# 2023-12-11 15:54:48.050 - [NOTICE] callbacks.on_step_start(180): Cycle 176/600, step 1/1: Charge at 1 C until 4.2 V
# 2023-12-11 15:54:49.798 - [NOTICE] callbacks.on_cycle_start(172): Cycle 177/600 (4 minutes, 43 seconds elapsed) --------------------
# 2023-12-11 15:54:49.799 - [NOTICE] callbacks.on_step_start(180): Cycle 177/600, step 1/1: Hold at 4.2 V until 50 mA
# 2023-12-11 15:54:52.861 - [NOTICE] callbacks.on_cycle_start(172): Cycle 178/600 (4 minutes, 46 seconds elapsed) --------------------
# 2023-12-11 15:54:52.863 - [NOTICE] callbacks.on_step_start(180): Cycle 178/600, step 1/1: Rest for 10 minutes
# 2023-12-11 15:54:53.677 - [NOTICE] callbacks.on_cycle_start(172): Cycle 179/600 (4 minutes, 47 seconds elapsed) --------------------
# 2023-12-11 15:54:53.678 - [NOTICE] callbacks.on_step_start(180): Cycle 179/600, step 1/1: Discharge at 1 C until 2.5 V
# 2023-12-11 15:54:55.949 - [NOTICE] callbacks.on_cycle_start(172): Cycle 180/600 (4 minutes, 49 seconds elapsed) --------------------
# 2023-12-11 15:54:55.951 - [NOTICE] callbacks.on_step_start(180): Cycle 180/600, step 1/1: Rest for 10 minutes
# 2023-12-11 15:54:56.719 - [NOTICE] callbacks.on_cycle_start(172): Cycle 181/600 (4 minutes, 50 seconds elapsed) --------------------
# 2023-12-11 15:54:56.720 - [NOTICE] callbacks.on_step_start(180): Cycle 181/600, step 1/1: Rest for 10 minutes
# 2023-12-11 15:54:57.530 - [NOTICE] callbacks.on_cycle_start(172): Cycle 182/600 (4 minutes, 51 seconds elapsed) --------------------
# 2023-12-11 15:54:57.531 - [NOTICE] callbacks.on_step_start(180): Cycle 182/600, step 1/1: Charge at 1 C until 4.2 V
# 2023-12-11 15:54:59.430 - [NOTICE] callbacks.on_cycle_start(172): Cycle 183/600 (4 minutes, 53 seconds elapsed) --------------------
# 2023-12-11 15:54:59.432 - [NOTICE] callbacks.on_step_start(180): Cycle 183/600, step 1/1: Hold at 4.2 V until 50 mA
# 2023-12-11 15:55:02.364 - [NOTICE] callbacks.on_cycle_start(172): Cycle 184/600 (4 minutes, 56 seconds elapsed) --------------------
# 2023-12-11 15:55:02.367 - [NOTICE] callbacks.on_step_start(180): Cycle 184/600, step 1/1: Rest for 10 minutes
# 2023-12-11 15:55:03.057 - [NOTICE] callbacks.on_cycle_start(172): Cycle 185/600 (4 minutes, 57 seconds elapsed) --------------------
# 2023-12-11 15:55:03.058 - [NOTICE] callbacks.on_step_start(180): Cycle 185/600, step 1/1: Discharge at 1 C until 2.5 V
# 2023-12-11 15:55:05.073 - [NOTICE] callbacks.on_cycle_start(172): Cycle 186/600 (4 minutes, 59 seconds elapsed) --------------------
# 2023-12-11 15:55:05.074 - [NOTICE] callbacks.on_step_start(180): Cycle 186/600, step 1/1: Rest for 10 minutes
# 2023-12-11 15:55:05.795 - [NOTICE] callbacks.on_cycle_start(172): Cycle 187/600 (4 minutes, 59 seconds elapsed) --------------------
# 2023-12-11 15:55:05.796 - [NOTICE] callbacks.on_step_start(180): Cycle 187/600, step 1/1: Rest for 10 minutes
# 2023-12-11 15:55:06.515 - [NOTICE] callbacks.on_cycle_start(172): Cycle 188/600 (5 minutes, 0 seconds elapsed) --------------------
# 2023-12-11 15:55:06.517 - [NOTICE] callbacks.on_step_start(180): Cycle 188/600, step 1/1: Charge at 1 C until 4.2 V
# 2023-12-11 15:55:08.069 - [NOTICE] callbacks.on_cycle_start(172): Cycle 189/600 (5 minutes, 2 seconds elapsed) --------------------
# 2023-12-11 15:55:08.070 - [NOTICE] callbacks.on_step_start(180): Cycle 189/600, step 1/1: Hold at 4.2 V until 50 mA
# 2023-12-11 15:55:10.867 - [NOTICE] callbacks.on_cycle_start(172): Cycle 190/600 (5 minutes, 4 seconds elapsed) --------------------
# 2023-12-11 15:55:10.869 - [NOTICE] callbacks.on_step_start(180): Cycle 190/600, step 1/1: Rest for 10 minutes
# 2023-12-11 15:55:11.592 - [NOTICE] callbacks.on_cycle_start(172): Cycle 191/600 (5 minutes, 5 seconds elapsed) --------------------
# 2023-12-11 15:55:11.594 - [NOTICE] callbacks.on_step_start(180): Cycle 191/600, step 1/1: Discharge at 1 C until 2.5 V
# 2023-12-11 15:55:13.867 - [NOTICE] callbacks.on_cycle_start(172): Cycle 192/600 (5 minutes, 7 seconds elapsed) --------------------
# 2023-12-11 15:55:13.868 - [NOTICE] callbacks.on_step_start(180): Cycle 192/600, step 1/1: Rest for 10 minutes
# 2023-12-11 15:55:14.628 - [NOTICE] callbacks.on_cycle_start(172): Cycle 193/600 (5 minutes, 8 seconds elapsed) --------------------
# 2023-12-11 15:55:14.629 - [NOTICE] callbacks.on_step_start(180): Cycle 193/600, step 1/1: Rest for 10 minutes
# 2023-12-11 15:55:15.414 - [NOTICE] callbacks.on_cycle_start(172): Cycle 194/600 (5 minutes, 9 seconds elapsed) --------------------
# 2023-12-11 15:55:15.415 - [NOTICE] callbacks.on_step_start(180): Cycle 194/600, step 1/1: Charge at 1 C until 4.2 V
# 2023-12-11 15:55:17.046 - [NOTICE] callbacks.on_cycle_start(172): Cycle 195/600 (5 minutes, 11 seconds elapsed) --------------------
# 2023-12-11 15:55:17.047 - [NOTICE] callbacks.on_step_start(180): Cycle 195/600, step 1/1: Hold at 4.2 V until 50 mA
# 2023-12-11 15:55:20.125 - [NOTICE] callbacks.on_cycle_start(172): Cycle 196/600 (5 minutes, 14 seconds elapsed) --------------------
# 2023-12-11 15:55:20.126 - [NOTICE] callbacks.on_step_start(180): Cycle 196/600, step 1/1: Rest for 10 minutes
# 2023-12-11 15:55:20.903 - [NOTICE] callbacks.on_cycle_start(172): Cycle 197/600 (5 minutes, 14 seconds elapsed) --------------------
# 2023-12-11 15:55:20.904 - [NOTICE] callbacks.on_step_start(180): Cycle 197/600, step 1/1: Discharge at 1 C until 2.5 V
# 2023-12-11 15:55:23.062 - [NOTICE] callbacks.on_cycle_start(172): Cycle 198/600 (5 minutes, 17 seconds elapsed) --------------------
# ...
# 2023-12-11 16:19:31.575 - [NOTICE] callbacks.on_cycle_start(172): Cycle 343/344 (2.217 s elapsed) --------------------
# 2023-12-11 16:19:31.577 - [NOTICE] callbacks.on_step_start(180): Cycle 343/344, step 1/1: Discharge at 5.11855628526636 A until 2.5 V
# 2023-12-11 16:19:32.868 - [NOTICE] callbacks.on_cycle_start(172): Cycle 344/344 (3.510 s elapsed) --------------------
# 2023-12-11 16:19:32.869 - [NOTICE] callbacks.on_step_start(180): Cycle 344/344, step 1/1: Hold at 2.5 V for 10 minutes
# 2023-12-11 16:19:33.734 - [NOTICE] callbacks.on_experiment_end(220): Finish experiment simulation, took 4.362 s
# 2023-12-11 16:19:37.807 - [NOTICE] callbacks.on_cycle_start(172): Cycle 345/348 (135.055 us elapsed) --------------------
# 2023-12-11 16:19:37.808 - [NOTICE] callbacks.on_step_start(180): Cycle 345/348, step 1/1: Charge at 5.118157096271586 A until 4.2 V
# 2023-12-11 16:19:39.065 - [NOTICE] callbacks.on_cycle_start(172): Cycle 346/348 (1.258 s elapsed) --------------------
# 2023-12-11 16:19:39.066 - [NOTICE] callbacks.on_step_start(180): Cycle 346/348, step 1/1: Hold at 4.2 V for 10 minutes
# 2023-12-11 16:19:39.888 - [NOTICE] callbacks.on_cycle_start(172): Cycle 347/348 (2.082 s elapsed) --------------------
# 2023-12-11 16:19:39.889 - [NOTICE] callbacks.on_step_start(180): Cycle 347/348, step 1/1: Discharge at 5.118157096271586 A until 2.5 V
# 2023-12-11 16:19:41.171 - [NOTICE] callbacks.on_cycle_start(172): Cycle 348/348 (3.365 s elapsed) --------------------
# 2023-12-11 16:19:41.172 - [NOTICE] callbacks.on_step_start(180): Cycle 348/348, step 1/1: Hold at 2.5 V for 10 minutes
# 2023-12-11 16:19:42.050 - [NOTICE] callbacks.on_experiment_end(220): Finish experiment simulation, took 4.231 s
# 2023-12-11 16:19:46.156 - [NOTICE] callbacks.on_cycle_start(172): Cycle 349/352 (142.429 us elapsed) --------------------
# 2023-12-11 16:19:46.157 - [NOTICE] callbacks.on_step_start(180): Cycle 349/352, step 1/1: Charge at 5.1177580911961025 A until 4.2 V
# 2023-12-11 16:19:47.387 - [NOTICE] callbacks.on_cycle_start(172): Cycle 350/352 (1.231 s elapsed) --------------------
# 2023-12-11 16:19:47.388 - [NOTICE] callbacks.on_step_start(180): Cycle 350/352, step 1/1: Hold at 4.2 V for 10 minutes
# 2023-12-11 16:19:48.205 - [NOTICE] callbacks.on_cycle_start(172): Cycle 351/352 (2.049 s elapsed) --------------------
# 2023-12-11 16:19:48.206 - [NOTICE] callbacks.on_step_start(180): Cycle 351/352, step 1/1: Discharge at 5.1177580911961025 A until 2.5 V
# 2023-12-11 16:19:49.496 - [NOTICE] callbacks.on_cycle_start(172): Cycle 352/352 (3.340 s elapsed) --------------------
# 2023-12-11 16:19:49.497 - [NOTICE] callbacks.on_step_start(180): Cycle 352/352, step 1/1: Hold at 2.5 V for 10 minutes
# 2023-12-11 16:19:50.365 - [NOTICE] callbacks.on_experiment_end(220): Finish experiment simulation, took 4.197 s
# 2023-12-11 16:19:54.316 - [NOTICE] callbacks.on_cycle_start(172): Cycle 353/356 (157.867 us elapsed) --------------------
# 2023-12-11 16:19:54.317 - [NOTICE] callbacks.on_step_start(180): Cycle 353/356, step 1/1: Charge at 5.117359269739229 A until 4.2 V
# 2023-12-11 16:19:55.609 - [NOTICE] callbacks.on_cycle_start(172): Cycle 354/356 (1.294 s elapsed) --------------------
# 2023-12-11 16:19:55.610 - [NOTICE] callbacks.on_step_start(180): Cycle 354/356, step 1/1: Hold at 4.2 V for 10 minutes
# 2023-12-11 16:19:56.439 - [NOTICE] callbacks.on_cycle_start(172): Cycle 355/356 (2.124 s elapsed) --------------------
# 2023-12-11 16:19:56.440 - [NOTICE] callbacks.on_step_start(180): Cycle 355/356, step 1/1: Discharge at 5.117359269739229 A until 2.5 V
# 2023-12-11 16:19:57.756 - [NOTICE] callbacks.on_cycle_start(172): Cycle 356/356 (3.440 s elapsed) --------------------
# 2023-12-11 16:19:57.757 - [NOTICE] callbacks.on_step_start(180): Cycle 356/356, step 1/1: Hold at 2.5 V for 10 minutes
# 2023-12-11 16:19:58.697 - [NOTICE] callbacks.on_experiment_end(220): Finish experiment simulation, took 4.369 s
# 2023-12-11 16:20:03.123 - [NOTICE] callbacks.on_cycle_start(172): Cycle 357/360 (197.435 us elapsed) --------------------
# 2023-12-11 16:20:03.124 - [NOTICE] callbacks.on_step_start(180): Cycle 357/360, step 1/1: Charge at 5.11696063153469 A until 4.2 V
# 2023-12-11 16:20:04.385 - [NOTICE] callbacks.on_cycle_start(172): Cycle 358/360 (1.263 s elapsed) --------------------
# 2023-12-11 16:20:04.387 - [NOTICE] callbacks.on_step_start(180): Cycle 358/360, step 1/1: Hold at 4.2 V for 10 minutes
# 2023-12-11 16:20:05.198 - [NOTICE] callbacks.on_cycle_start(172): Cycle 359/360 (2.075 s elapsed) --------------------
# 2023-12-11 16:20:05.199 - [NOTICE] callbacks.on_step_start(180): Cycle 359/360, step 1/1: Discharge at 5.11696063153469 A until 2.5 V
# 2023-12-11 16:20:06.439 - [NOTICE] callbacks.on_cycle_start(172): Cycle 360/360 (3.316 s elapsed) --------------------
# 2023-12-11 16:20:06.440 - [NOTICE] callbacks.on_step_start(180): Cycle 360/360, step 1/1: Hold at 2.5 V for 10 minutes
# 2023-12-11 16:20:07.277 - [NOTICE] callbacks.on_experiment_end(220): Finish experiment simulation, took 4.141 s
# 2023-12-11 16:20:11.353 - [NOTICE] callbacks.on_cycle_start(172): Cycle 361/364 (146.382 us elapsed) --------------------
# 2023-12-11 16:20:11.354 - [NOTICE] callbacks.on_step_start(180): Cycle 361/364, step 1/1: Charge at 5.116562176420746 A until 4.2 V
# 2023-12-11 16:20:12.654 - [NOTICE] callbacks.on_cycle_start(172): Cycle 362/364 (1.301 s elapsed) --------------------
# 2023-12-11 16:20:12.655 - [NOTICE] callbacks.on_step_start(180): Cycle 362/364, step 1/1: Hold at 4.2 V for 10 minutes
# 2023-12-11 16:20:13.495 - [NOTICE] callbacks.on_cycle_start(172): Cycle 363/364 (2.142 s elapsed) --------------------
# 2023-12-11 16:20:13.495 - [NOTICE] callbacks.on_step_start(180): Cycle 363/364, step 1/1: Discharge at 5.116562176420746 A until 2.5 V
# 2023-12-11 16:20:14.762 - [NOTICE] callbacks.on_cycle_start(172): Cycle 364/364 (3.410 s elapsed) --------------------
# 2023-12-11 16:20:14.764 - [NOTICE] callbacks.on_step_start(180): Cycle 364/364, step 1/1: Hold at 2.5 V for 10 minutes
# 2023-12-11 16:20:15.593 - [NOTICE] callbacks.on_experiment_end(220): Finish experiment simulation, took 4.226 s
# 2023-12-11 16:20:19.767 - [NOTICE] callbacks.on_cycle_start(172): Cycle 365/368 (198.636 us elapsed) --------------------
# 2023-12-11 16:20:19.768 - [NOTICE] callbacks.on_step_start(180): Cycle 365/368, step 1/1: Charge at 5.1161639041131375 A until 4.2 V
# 2023-12-11 16:20:21.060 - [NOTICE] callbacks.on_cycle_start(172): Cycle 366/368 (1.293 s elapsed) --------------------
# 2023-12-11 16:20:21.061 - [NOTICE] callbacks.on_step_start(180): Cycle 366/368, step 1/1: Hold at 4.2 V for 10 minutes
# 2023-12-11 16:20:21.868 - [NOTICE] callbacks.on_cycle_start(172): Cycle 367/368 (2.101 s elapsed) --------------------
# 2023-12-11 16:20:21.869 - [NOTICE] callbacks.on_step_start(180): Cycle 367/368, step 1/1: Discharge at 5.1161639041131375 A until 2.5 V
# 2023-12-11 16:20:23.133 - [NOTICE] callbacks.on_cycle_start(172): Cycle 368/368 (3.367 s elapsed) --------------------
# 2023-12-11 16:20:23.135 - [NOTICE] callbacks.on_step_start(180): Cycle 368/368, step 1/1: Hold at 2.5 V for 10 minutes
# 2023-12-11 16:20:24.158 - [NOTICE] callbacks.on_experiment_end(220): Finish experiment simulation, took 4.375 s
# 2023-12-11 16:20:28.497 - [NOTICE] callbacks.on_cycle_start(172): Cycle 369/372 (141.461 us elapsed) --------------------
# 2023-12-11 16:20:28.498 - [NOTICE] callbacks.on_step_start(180): Cycle 369/372, step 1/1: Charge at 5.1157658143434634 A until 4.2 V
# 2023-12-11 16:20:29.827 - [NOTICE] callbacks.on_cycle_start(172): Cycle 370/372 (1.331 s elapsed) --------------------
# 2023-12-11 16:20:29.829 - [NOTICE] callbacks.on_step_start(180): Cycle 370/372, step 1/1: Hold at 4.2 V for 10 minutes
# 2023-12-11 16:20:30.679 - [NOTICE] callbacks.on_cycle_start(172): Cycle 371/372 (2.183 s elapsed) --------------------
# 2023-12-11 16:20:30.681 - [NOTICE] callbacks.on_step_start(180): Cycle 371/372, step 1/1: Discharge at 5.1157658143434634 A until 2.5 V
# 2023-12-11 16:20:31.918 - [NOTICE] callbacks.on_cycle_start(172): Cycle 372/372 (3.422 s elapsed) --------------------
# 2023-12-11 16:20:31.920 - [NOTICE] callbacks.on_step_start(180): Cycle 372/372, step 1/1: Hold at 2.5 V for 10 minutes
# 2023-12-11 16:20:32.792 - [NOTICE] callbacks.on_experiment_end(220): Finish experiment simulation, took 4.281 s
# 2023-12-11 16:20:43.876 - [NOTICE] callbacks.on_cycle_start(172): Cycle 373/376 (139.576 us elapsed) --------------------
# 2023-12-11 16:20:43.877 - [NOTICE] callbacks.on_step_start(180): Cycle 373/376, step 1/1: Charge at 5.115367906819079 A until 4.2 V
# 2023-12-11 16:20:45.285 - [NOTICE] callbacks.on_cycle_start(172): Cycle 374/376 (1.409 s elapsed) --------------------
# 2023-12-11 16:20:45.286 - [NOTICE] callbacks.on_step_start(180): Cycle 374/376, step 1/1: Hold at 4.2 V for 10 minutes
# 2023-12-11 16:20:46.164 - [NOTICE] callbacks.on_cycle_start(172): Cycle 375/376 (2.288 s elapsed) --------------------
# 2023-12-11 16:20:46.165 - [NOTICE] callbacks.on_step_start(180): Cycle 375/376, step 1/1: Discharge at 5.115367906819079 A until 2.5 V
# 2023-12-11 16:20:47.412 - [NOTICE] callbacks.on_cycle_start(172): Cycle 376/376 (3.537 s elapsed) --------------------
# 2023-12-11 16:20:47.413 - [NOTICE] callbacks.on_step_start(180): Cycle 376/376, step 1/1: Hold at 2.5 V for 10 minutes
# 2023-12-11 16:20:48.269 - [NOTICE] callbacks.on_experiment_end(220): Finish experiment simulation, took 4.380 s
# 2023-12-11 16:20:52.518 - [NOTICE] callbacks.on_cycle_start(172): Cycle 377/380 (145.183 us elapsed) --------------------
# 2023-12-11 16:20:52.519 - [NOTICE] callbacks.on_step_start(180): Cycle 377/380, step 1/1: Charge at 5.114970181277133 A until 4.2 V
# 2023-12-11 16:20:53.817 - [NOTICE] callbacks.on_cycle_start(172): Cycle 378/380 (1.299 s elapsed) --------------------
# 2023-12-11 16:20:53.818 - [NOTICE] callbacks.on_step_start(180): Cycle 378/380, step 1/1: Hold at 4.2 V for 10 minutes
# 2023-12-11 16:20:54.679 - [NOTICE] callbacks.on_cycle_start(172): Cycle 379/380 (2.162 s elapsed) --------------------
# 2023-12-11 16:20:54.680 - [NOTICE] callbacks.on_step_start(180): Cycle 379/380, step 1/1: Discharge at 5.114970181277133 A until 2.5 V
# 2023-12-11 16:20:55.962 - [NOTICE] callbacks.on_cycle_start(172): Cycle 380/380 (3.444 s elapsed) --------------------
# 2023-12-11 16:20:55.963 - [NOTICE] callbacks.on_step_start(180): Cycle 380/380, step 1/1: Hold at 2.5 V for 10 minutes
# 2023-12-11 16:20:56.870 - [NOTICE] callbacks.on_experiment_end(220): Finish experiment simulation, took 4.338 s
# 2023-12-11 16:21:01.135 - [NOTICE] callbacks.on_cycle_start(172): Cycle 381/384 (141.698 us elapsed) --------------------
# 2023-12-11 16:21:01.136 - [NOTICE] callbacks.on_step_start(180): Cycle 381/384, step 1/1: Charge at 5.114572637469828 A until 4.2 V
# 2023-12-11 16:21:02.372 - [NOTICE] callbacks.on_cycle_start(172): Cycle 382/384 (1.237 s elapsed) --------------------
# 2023-12-11 16:21:02.373 - [NOTICE] callbacks.on_step_start(180): Cycle 382/384, step 1/1: Hold at 4.2 V for 10 minutes
# 2023-12-11 16:21:03.185 - [NOTICE] callbacks.on_cycle_start(172): Cycle 383/384 (2.050 s elapsed) --------------------
# 2023-12-11 16:21:03.186 - [NOTICE] callbacks.on_step_start(180): Cycle 383/384, step 1/1: Discharge at 5.114572637469828 A until 2.5 V
# 2023-12-11 16:21:04.451 - [NOTICE] callbacks.on_cycle_start(172): Cycle 384/384 (3.316 s elapsed) --------------------
# 2023-12-11 16:21:04.452 - [NOTICE] callbacks.on_step_start(180): Cycle 384/384, step 1/1: Hold at 2.5 V for 10 minutes
# 2023-12-11 16:21:05.299 - [NOTICE] callbacks.on_experiment_end(220): Finish experiment simulation, took 4.149 s
# 2023-12-11 16:21:09.429 - [NOTICE] callbacks.on_cycle_start(172): Cycle 385/388 (146.306 us elapsed) --------------------
# 2023-12-11 16:21:09.430 - [NOTICE] callbacks.on_step_start(180): Cycle 385/388, step 1/1: Charge at 5.11417527512225 A until 4.2 V
# 2023-12-11 16:21:10.660 - [NOTICE] callbacks.on_cycle_start(172): Cycle 386/388 (1.231 s elapsed) --------------------
# 2023-12-11 16:21:10.662 - [NOTICE] callbacks.on_step_start(180): Cycle 386/388, step 1/1: Hold at 4.2 V for 10 minutes
# 2023-12-11 16:21:11.479 - [NOTICE] callbacks.on_cycle_start(172): Cycle 387/388 (2.050 s elapsed) --------------------
# 2023-12-11 16:21:11.480 - [NOTICE] callbacks.on_step_start(180): Cycle 387/388, step 1/1: Discharge at 5.11417527512225 A until 2.5 V
# 2023-12-11 16:21:12.726 - [NOTICE] callbacks.on_cycle_start(172): Cycle 388/388 (3.297 s elapsed) --------------------
# 2023-12-11 16:21:12.727 - [NOTICE] callbacks.on_step_start(180): Cycle 388/388, step 1/1: Hold at 2.5 V for 10 minutes
# 2023-12-11 16:21:13.592 - [NOTICE] callbacks.on_experiment_end(220): Finish experiment simulation, took 4.148 s
# 2023-12-11 16:21:17.713 - [NOTICE] callbacks.on_cycle_start(172): Cycle 389/392 (147.901 us elapsed) --------------------
# 2023-12-11 16:21:17.714 - [NOTICE] callbacks.on_step_start(180): Cycle 389/392, step 1/1: Charge at 5.113778094054295 A until 4.2 V
# 2023-12-11 16:21:19.030 - [NOTICE] callbacks.on_cycle_start(172): Cycle 390/392 (1.317 s elapsed) --------------------
# 2023-12-11 16:21:19.031 - [NOTICE] callbacks.on_step_start(180): Cycle 390/392, step 1/1: Hold at 4.2 V for 10 minutes
# 2023-12-11 16:21:19.863 - [NOTICE] callbacks.on_cycle_start(172): Cycle 391/392 (2.151 s elapsed) --------------------
# 2023-12-11 16:21:19.864 - [NOTICE] callbacks.on_step_start(180): Cycle 391/392, step 1/1: Discharge at 5.113778094054295 A until 2.5 V
# 2023-12-11 16:21:21.062 - [NOTICE] callbacks.on_cycle_start(172): Cycle 392/392 (3.350 s elapsed) --------------------
# 2023-12-11 16:21:21.063 - [NOTICE] callbacks.on_step_start(180): Cycle 392/392, step 1/1: Hold at 2.5 V for 10 minutes
# 2023-12-11 16:21:21.909 - [NOTICE] callbacks.on_experiment_end(220): Finish experiment simulation, took 4.182 s
# 2023-12-11 16:21:26.028 - [NOTICE] callbacks.on_cycle_start(172): Cycle 393/396 (148.988 us elapsed) --------------------
# 2023-12-11 16:21:26.029 - [NOTICE] callbacks.on_step_start(180): Cycle 393/396, step 1/1: Charge at 5.113381093897039 A until 4.2 V
# 2023-12-11 16:21:27.603 - [NOTICE] callbacks.on_cycle_start(172): Cycle 394/396 (1.576 s elapsed) --------------------
# 2023-12-11 16:21:27.604 - [NOTICE] callbacks.on_step_start(180): Cycle 394/396, step 1/1: Hold at 4.2 V for 10 minutes
# 2023-12-11 16:21:28.414 - [NOTICE] callbacks.on_cycle_start(172): Cycle 395/396 (2.386 s elapsed) --------------------
# 2023-12-11 16:21:28.415 - [NOTICE] callbacks.on_step_start(180): Cycle 395/396, step 1/1: Discharge at 5.113381093897039 A until 2.5 V
# 2023-12-11 16:21:29.990 - [NOTICE] callbacks.on_cycle_start(172): Cycle 396/396 (3.962 s elapsed) --------------------
# 2023-12-11 16:21:29.991 - [NOTICE] callbacks.on_step_start(180): Cycle 396/396, step 1/1: Hold at 2.5 V for 10 minutes
# 2023-12-11 16:21:30.822 - [NOTICE] callbacks.on_experiment_end(220): Finish experiment simulation, took 4.779 s
# 2023-12-11 16:21:34.980 - [NOTICE] callbacks.on_cycle_start(172): Cycle 397/400 (150.643 us elapsed) --------------------
# 2023-12-11 16:21:34.981 - [NOTICE] callbacks.on_step_start(180): Cycle 397/400, step 1/1: Charge at 5.112984265497641 A until 4.2 V
# 2023-12-11 16:21:36.616 - [NOTICE] callbacks.on_cycle_start(172): Cycle 398/400 (1.636 s elapsed) --------------------
# 2023-12-11 16:21:36.617 - [NOTICE] callbacks.on_step_start(180): Cycle 398/400, step 1/1: Hold at 4.2 V for 10 minutes
# 2023-12-11 16:21:37.590 - [NOTICE] callbacks.on_cycle_start(172): Cycle 399/400 (2.611 s elapsed) --------------------
# 2023-12-11 16:21:37.591 - [NOTICE] callbacks.on_step_start(180): Cycle 399/400, step 1/1: Discharge at 5.112984265497641 A until 2.5 V
# 2023-12-11 16:21:39.334 - [NOTICE] callbacks.on_cycle_start(172): Cycle 400/400 (4.355 s elapsed) --------------------
# 2023-12-11 16:21:39.335 - [NOTICE] callbacks.on_step_start(180): Cycle 400/400, step 1/1: Hold at 2.5 V for 10 minutes
# 2023-12-11 16:21:40.207 - [NOTICE] callbacks.on_experiment_end(220): Finish experiment simulation, took 5.213 s

# %%
len(cyc)
# Out:
# 5

# %%
cyc = []
cycle_N = 3
times = [5,2,3,4]
cycle_numbers = [cycle_N] * len(times)
cyc.append(cycle_numbers)
print(cycle_numbers)
print(cyc)
# Out:
# [3, 3, 3, 3]
# [[3, 3, 3, 3]]
